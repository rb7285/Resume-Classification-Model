# %%
import os
import csv
import docx2txt
import fitz 
import pandas as pd
import matplotlib as plt


from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
def read_docx(file_path):
    text = docx2txt.process(file_path)
    return text
    with Exception as e :
        print(f"Error processing {file_path} : {e}")
        return ""

# %%
def read_pdf(file_path):
    text = ""
    with fitz.open(file_path) as pdf:
        for page in pdf:
            text += page.get_text("text")
    return text

# %%
def process_resumes_to_csv(folder_path, output_csv):
    with open(output_csv, mode="w", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(["File Name", "Category", "Content"])  
        for root, dirs, files in os.walk(folder_path):
            folder_name = os.path.basename(root)  
            for file in files:
                file_path = os.path.join(root, file)
                resume_text = ""
                try:
                    if file.endswith(".docx"):
                        resume_text = read_docx(file_path)
                    elif file.endswith(".pdf"):
                        resume_text = read_pdf(file_path)
                    else:
                        print(f"Skipped unsupported file format: {file}")
                        continue
                    writer.writerow([file, folder_name, resume_text])
                    print(f"Processed: {file} in folder: {folder_name}")

                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
                    
folder_path = r'C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx'
output_csv = 'files_to_csv_resumes1.csv'
process_resumes_to_csv(folder_path, output_csv)
# Out:
# Processed: Peoplesoft Admin_AnubhavSingh.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Admin_G Ananda Rayudu.doc
# Processed: Peoplesoft Admin_G Ananda Rayudu.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Admin_Gangareddy.doc
# Processed: Peoplesoft Admin_Gangareddy.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft Admin_Murali.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Admin_Priyanka Ramadoss.doc
# Processed: Peoplesoft Admin_Priyanka Ramadoss.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft Admin_SirazuddinMohammad.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Admin_srinivasarao.doc
# Processed: Peoplesoft Admin_srinivasarao.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft Admin_Varkala Vikas.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Admin_Vinod Akkala.doc
# Processed: Peoplesoft Admin_Vinod Akkala.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: PeopleSoft DBA_Ganesh Alladi.doc
# Processed: PeopleSoft DBA_Ganesh Alladi.docx in folder: Peoplesoft Resume
# Processed: PeopleSoft DBA_Vivekanand Sayana.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Finance_Arun Venu.doc
# Processed: Peoplesoft Finance_Arun Venu.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Finance_Pritam Biswas.doc
# Processed: Peoplesoft Finance_Pritam Biswas.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft Finance_Rahul Ahuja.doc
# Processed: Peoplesoft Finance_Rahul Ahuja.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft FSCM_HariNarayana.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft FSCM_Murali.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft FSCM_PriyabrataHota.docx in folder: Peoplesoft Resume
# Skipped unsupported file format: Peoplesoft FSCM_R Ahmed.doc
# Processed: Peoplesoft FSCM_R Ahmed.docx in folder: Peoplesoft Resume
# Processed: Peoplesoft FSCM_SUJATHA.docx in folder: Peoplesoft Resume
# Processed: Resume_Subha Santosh_Peoplesoft FSCM.docx in folder: Peoplesoft Resume
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft Admin_Vinod Akkala.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$opleSoft DBA_Ganesh Alladi.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$opleSoft DBA_Vivekanand Sayana.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft Finance_Arun Venu.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft Finance_Pritam Biswas.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft Finance_Rahul Ahuja.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft FSCM_HariNarayana.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft FSCM_Murali.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft FSCM_PriyabrataHota.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft FSCM_R Ahmed.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$oplesoft FSCM_SUJATHA.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\Peoplesoft Resume\~$sume_Subha Santosh_Peoplesoft FSCM.docx: File is not a zip file
# Processed: Internship_Ravali_Musquare Technologies (1).docx in folder: React Developer
# Processed: Internship_Susovan Bag_Musquare Technologies.docx in folder: React Developer
# Processed: React Developer_Deepakreddy.docx in folder: React Developer
# Processed: React Developer_Haripriya.docx in folder: React Developer
# Processed: React Developer_Kamalakar Reddy.docx in folder: React Developer
# Processed: React Developer_Naveen sadhu.docx in folder: React Developer
# Skipped unsupported file format: React Developer_PavasGoswami.doc
# Processed: React Developer_PavasGoswami.docx in folder: React Developer
# Processed: React Developer_Pragnya.docx in folder: React Developer
# Processed: React Developer_Sarala Madasu-converted.docx in folder: React Developer
# Processed: React Developer_Thirupathiamma.docx in folder: React Developer
# Skipped unsupported file format: React Developer_Vinay Reddy.doc
# Processed: React Developer_Vinay Reddy.docx in folder: React Developer
# Processed: React Dev_Krishna Kanth.docx in folder: React Developer
# Processed: React Dev_Krishna Kanth_Musquare Technologies.docx in folder: React Developer
# Skipped unsupported file format: React JS Developer_AnjaniPriyadarshini.doc
# Processed: React JS Developer_AnjaniPriyadarshini.docx in folder: React Developer
# Processed: React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx in folder: React Developer
# Processed: React JS Developer_Venkatalakshmi (1)-converted.docx in folder: React Developer
# Processed: Reactjs Developer_kambala sai surendra_Musquare Technologies.docx in folder: React Developer
# Processed: Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx in folder: React Developer
# Processed: Reactjs Developer_M Lokesh.docx in folder: React Developer
# Processed: Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx in folder: React Developer
# Processed: Reactjs Developer_Prabakaran_Musquare Technologies.pdf in folder: React Developer
# Processed: Reactjs Developer_Pranish Sonone_Musquare Technologies.docx in folder: React Developer
# Processed: Reactjs Developer_Ranga Gaganam_Musquare Technologies.docx in folder: React Developer
# Processed: Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx in folder: React Developer
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Deepakreddy.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Haripriya.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Kamalakar Reddy.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Naveen sadhu.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_PavasGoswami.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Pragnya.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Sarala Madasu-converted.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Thirupathiamma.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Developer_Vinay Reddy.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Dev_Krishna Kanth.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act Dev_Krishna Kanth_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act JS Developer_AnjaniPriyadarshini.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$act JS Developer_Venkatalakshmi (1)-converted.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_kambala sai surendra_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_M Lokesh Babu_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_M Lokesh.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_Pranish Sonone_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_Ranga Gaganam_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$actjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$ternship_Ravali_Musquare Technologies (1).docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\React Developer\~$ternship_Susovan Bag_Musquare Technologies.docx: File is not a zip file
# Processed: Anil kumar.docx in folder: SQL Developer
# Processed: AradhanaTripathi[4_0].docx in folder: SQL Developer
# Processed: Buddha Vamsi.docx in folder: SQL Developer
# Processed: kamballapradeep.docx in folder: SQL Developer
# Skipped unsupported file format: Nazeer Basha.doc
# Processed: Nazeer Basha.docx in folder: SQL Developer
# Processed: Neeraj Mishra.docx in folder: SQL Developer
# Processed: premsai.docx in folder: SQL Developer
# Skipped unsupported file format: Priyanka L.doc
# Processed: Priyanka L.docx in folder: SQL Developer
# Processed: PSyamKumar[2_3].docx in folder: SQL Developer
# Processed: Rajupavanakumari[2_10].docx in folder: SQL Developer
# Processed: Ramalakshmi K.docx in folder: SQL Developer
# Processed: RameshNataru[3_4].docx in folder: SQL Developer
# Skipped unsupported file format: Tatikonda Kiran Kumar.doc
# Processed: Tatikonda Kiran Kumar.docx in folder: SQL Developer
# Processed: Vinod B.docx in folder: SQL Developer
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\SQL Developer\~$adhanaTripathi[4_0].docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\SQL Developer\~$ddha Vamsi.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\SQL Developer\~$il kumar.docx: File is not a zip file
# Error reading C:\Users\HP\Documents\DataScienceCourse\Resume Classification Project\Resumes_Docx\SQL Developer\~$mballapradeep.docx: File is not a zip file
# Processed: ChinnaSubbarayuduM_Hexaware.docx in folder: workday
# Processed: Gopi Krishna_Hexaware.docx in folder: workday
# Skipped unsupported file format: Hari Krishna M_Hexaware.doc
# Processed: Hari Krishna M_Hexaware.docx in folder: workday
# Skipped unsupported file format: Harikrishna Akula_Hexaware.doc
# Processed: Harikrishna Akula_Hexaware.docx in folder: workday
# Skipped unsupported file format: Hima Mendu_Hexaware.doc
# Processed: Hima Mendu_Hexaware.docx in folder: workday
# Processed: Himaja G_(Hexaware).docx in folder: workday
# Skipped unsupported file format: J. Sumanth Royal_Hexaware.doc
# Processed: J. Sumanth Royal_Hexaware.docx in folder: workday
# Processed: Jyotiverma_Heaware.docx in folder: workday
# Skipped unsupported file format: Madeeswar A_Hexaware.doc
# Processed: Madeeswar A_Hexaware.docx in folder: workday
# Processed: MooraboyinaGuravaiah_Hexaware.docx in folder: workday
# Skipped unsupported file format: Naresh Babu Cherukuri_Hexaware.doc
# Processed: Naresh Babu Cherukuri_Hexaware.docx in folder: workday
# Processed: P V Sai Krishna_ Hexaware.docx in folder: workday
# Skipped unsupported file format: Punugoti Swetha_Hexaware.doc
# Processed: Punugoti Swetha_Hexaware.docx in folder: workday
# Processed: RahulM_Hexaware.docx in folder: workday
# Processed: RameshP_Hexaware.docx in folder: workday
# Skipped unsupported file format: ShireeshKumar_Hexaware.doc
# Processed: ShireeshKumar_Hexaware.docx in folder: workday
# Skipped unsupported file format: Sri Krishna S_Hexaware.doc
# Processed: Sri Krishna S_Hexaware.docx in folder: workday
# Processed: Srikanth-Hexaware.docx in folder: workday
# Processed: SSKumar_Hexaware.docx in folder: workday
# Skipped unsupported file format: Venkateswarlu B_Hexaware.doc
# Processed: Venkateswarlu B_Hexaware.docx in folder: workday
# Processed: Vinay Kumar_Hexaware.docx in folder: workday

# %% [markdown]
# ## EDA

# %%
import pandas as pd
data = pd.read_csv("files_to_csv_resumes1.csv")
data
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                               Content
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   G. Ananda Rayudu \n\n\t\t       https://www.li...
# 2   PeopleSoft Database Administrator\n\n         ...
# 3   Classification: Internal\n\nClassification: In...
# 4   Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...
# ..                                                ...
# 74  Workday Integration Consultant\n\n\n\nName    ...
# 75  Srikanth (WORKDAY hCM Consultant)\t           ...
# 76  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 77  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
# 78  Vinay kumar .v\nWorkday Functional Consultant\...
#
# [79 rows x 3 columns]

# %%
data.head(80)
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                               Content
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   G. Ananda Rayudu \n\n\t\t       https://www.li...
# 2   PeopleSoft Database Administrator\n\n         ...
# 3   Classification: Internal\n\nClassification: In...
# 4   Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...
# ..                                                ...
# 74  Workday Integration Consultant\n\n\n\nName    ...
# 75  Srikanth (WORKDAY hCM Consultant)\t           ...
# 76  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 77  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
# 78  Vinay kumar .v\nWorkday Functional Consultant\...
#
# [79 rows x 3 columns]

# %% [markdown]
# ### EDA

# %%
data.shape
# Out:
# (79, 3)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# File Name    0
# Category     0
# Content      0
# dtype: int64

# %%
data.describe()
# Out:
#                                  File Name         Category  \
# count                                   79               79
# unique                                  79                4
# top     Peoplesoft Admin_AnubhavSingh.docx  React Developer
# freq                                     1               24
#
#                                                   Content
# count                                                  79
# unique                                                 79
# top     Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# freq                                                    1

# %%
data
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                               Content
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   G. Ananda Rayudu \n\n\t\t       https://www.li...
# 2   PeopleSoft Database Administrator\n\n         ...
# 3   Classification: Internal\n\nClassification: In...
# 4   Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...
# ..                                                ...
# 74  Workday Integration Consultant\n\n\n\nName    ...
# 75  Srikanth (WORKDAY hCM Consultant)\t           ...
# 76  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 77  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
# 78  Vinay kumar .v\nWorkday Functional Consultant\...
#
# [79 rows x 3 columns]

# %% [markdown]
# ##### Bar Chart

# %%
folder_file_count = data.groupby('Category')['File Name'].count()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
folder_file_count.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Number of Files Per Folder', fontsize=16)
plt.xlabel('Folder Name', fontsize=14)
plt.ylabel('Number of Files', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Histogram

# %%
data['data_length'] = data['Content'].str.len()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['data_length'], bins=20, color='lightcoral', edgecolor='black', alpha=0.7)

plt.title('Distribution of Data Length', fontsize=16)
plt.xlabel('Length of Data (characters)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Pie Chart

# %%
plt.figure(figsize=(8, 8))
folder_file_count.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

plt.title('File Distribution by Folder', fontsize=16)

plt.ylabel('')  
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Word Cloud

# %%
from wordcloud import WordCloud

text_data = ' '.join(data['Content'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text_data)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.title('Most Frequent Words in Data', fontsize=16)
plt.tight_layout()
plt.show()

# %%
data
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                               Content  data_length
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...         8010
# 1   G. Ananda Rayudu \n\n\t\t       https://www.li...         8318
# 2   PeopleSoft Database Administrator\n\n         ...         6900
# 3   Classification: Internal\n\nClassification: In...         4917
# 4   Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...         5196
# ..                                                ...          ...
# 74  Workday Integration Consultant\n\n\n\nName    ...         7030
# 75  Srikanth (WORKDAY hCM Consultant)\t           ...         6737
# 76  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...         8329
# 77  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...         6836
# 78  Vinay kumar .v\nWorkday Functional Consultant\...         5126
#
# [79 rows x 4 columns]

# %%
data.drop(['data_length'], axis = 1, inplace = True)

# %% [markdown]
# Data Cleaning

# %%
def preprocess(text):
    return text.lower()
data['Resume_Details'] = data.Content.apply(lambda x: preprocess(x))

# %%
import nltk
from nltk.corpus import stopwords

# %%
import re
def clean(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    email_pattern = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b')
    clean_text = url_pattern.sub('', text)
    clean_text = email_pattern.sub('', clean_text)
    
    clean_text = re.sub('[^\w\s]', '', clean_text)
    stop_words = set(stopwords.words('english'))
    clean_text  = ' '.join(word for word in clean_text.split() if word.lower() not in stop_words)
    
    return clean_text

# %%
data['Resume_Details'] = data['Resume_Details'].apply(lambda x:clean(x))

# %%
data
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                               Content  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   G. Ananda Rayudu \n\n\t\t       https://www.li...
# 2   PeopleSoft Database Administrator\n\n         ...
# 3   Classification: Internal\n\nClassification: In...
# 4   Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...
# ..                                                ...
# 74  Workday Integration Consultant\n\n\n\nName    ...
# 75  Srikanth (WORKDAY hCM Consultant)\t           ...
# 76  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 77  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
# 78  Vinay kumar .v\nWorkday Functional Consultant\...
#
#                                        Resume_Details
# 0   anubhav kumar singh core competencies scriptin...
# 1   g ananda rayudu profile summary 7 years experi...
# 2   peoplesoft database administrator gangareddy p...
# 3   classification internal classification interna...
# 4   priyanka ramadoss 6146 mountpleasant coonoor n...
# ..                                                ...
# 74  workday integration consultant name sri krishn...
# 75  srikanth workday hcm consultant seeking suitab...
# 76  workday hcm fcm name kumar ss role workday con...
# 77  venkateswarlub workday consultant professional...
# 78  vinay kumar v workday functional consultant ex...
#
# [79 rows x 4 columns]

# %%
data.drop(['Content'], axis = 1, inplace = True)
data
# Out:
#                                   File Name           Category  \
# 0        Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resume
# 1     Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resume
# 2          Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resume
# 3              Peoplesoft Admin_Murali.docx  Peoplesoft Resume
# 4   Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resume
# ..                                      ...                ...
# 74              Sri Krishna S_Hexaware.docx            workday
# 75                   Srikanth-Hexaware.docx            workday
# 76                    SSKumar_Hexaware.docx            workday
# 77            Venkateswarlu B_Hexaware.docx            workday
# 78                Vinay Kumar_Hexaware.docx            workday
#
#                                        Resume_Details
# 0   anubhav kumar singh core competencies scriptin...
# 1   g ananda rayudu profile summary 7 years experi...
# 2   peoplesoft database administrator gangareddy p...
# 3   classification internal classification interna...
# 4   priyanka ramadoss 6146 mountpleasant coonoor n...
# ..                                                ...
# 74  workday integration consultant name sri krishn...
# 75  srikanth workday hcm consultant seeking suitab...
# 76  workday hcm fcm name kumar ss role workday con...
# 77  venkateswarlub workday consultant professional...
# 78  vinay kumar v workday functional consultant ex...
#
# [79 rows x 3 columns]

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
le = LabelEncoder()
le.fit(data[['Category']])
data['Category'] = le.transform(data['Category'])
data['Category'] += 1

# %%
data['Category'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
data.head(40)
# Out:
#                                             File Name  Category  \
# 0                  Peoplesoft Admin_AnubhavSingh.docx         1
# 1               Peoplesoft Admin_G Ananda Rayudu.docx         1
# 2                    Peoplesoft Admin_Gangareddy.docx         1
# 3                        Peoplesoft Admin_Murali.docx         1
# 4             Peoplesoft Admin_Priyanka Ramadoss.docx         1
# 5            Peoplesoft Admin_SirazuddinMohammad.docx         1
# 6                  Peoplesoft Admin_srinivasarao.docx         1
# 7                 Peoplesoft Admin_Varkala Vikas.docx         1
# 8                  Peoplesoft Admin_Vinod Akkala.docx         1
# 9                   PeopleSoft DBA_Ganesh Alladi.docx         1
# 10              PeopleSoft DBA_Vivekanand Sayana.docx         1
# 11                  Peoplesoft Finance_Arun Venu.docx         1
# 12              Peoplesoft Finance_Pritam Biswas.docx         1
# 13                Peoplesoft Finance_Rahul Ahuja.docx         1
# 14                  Peoplesoft FSCM_HariNarayana.docx         1
# 15                        Peoplesoft FSCM_Murali.docx         1
# 16                Peoplesoft FSCM_PriyabrataHota.docx         1
# 17                       Peoplesoft FSCM_R Ahmed.docx         1
# 18                       Peoplesoft FSCM_SUJATHA.docx         1
# 19          Resume_Subha Santosh_Peoplesoft FSCM.docx         1
# 20   Internship_Ravali_Musquare Technologies (1).docx         2
# 21  Internship_Susovan Bag_Musquare Technologies.docx         2
# 22                   React Developer_Deepakreddy.docx         2
# 23                     React Developer_Haripriya.docx         2
# 24               React Developer_Kamalakar Reddy.docx         2
# 25                  React Developer_Naveen sadhu.docx         2
# 26                  React Developer_PavasGoswami.docx         2
# 27                       React Developer_Pragnya.docx         2
# 28       React Developer_Sarala Madasu-converted.docx         2
# 29                React Developer_Thirupathiamma.docx         2
# 30                   React Developer_Vinay Reddy.docx         2
# 31                       React Dev_Krishna Kanth.docx         2
# 32  React Dev_Krishna Kanth_Musquare Technologies....         2
# 33        React JS Developer_AnjaniPriyadarshini.docx         2
# 34  React JS Developer_KotaniDurgaprasad[3_1] (1)-...         2
# 35  React JS Developer_Venkatalakshmi (1)-converte...         2
# 36  Reactjs Developer_kambala sai surendra_Musquar...         2
# 37  Reactjs Developer_M Lokesh Babu_Musquare Techn...         2
# 38                    Reactjs Developer_M Lokesh.docx         2
# 39  Reactjs Developer_MD Khizaruddin Rauf _Musquar...         2
#
#                                        Resume_Details
# 0   anubhav kumar singh core competencies scriptin...
# 1   g ananda rayudu profile summary 7 years experi...
# 2   peoplesoft database administrator gangareddy p...
# 3   classification internal classification interna...
# 4   priyanka ramadoss 6146 mountpleasant coonoor n...
# 5   sirazuddin bangalore india sirazuddin bangalor...
# 6   peoplesoft administrator srinivask experience ...
# 7   peoplesoft admin varkala vikas career objectiv...
# 8   vinod akkala peoplesoft dba admin professional...
# 9   peoplesoft adminpeoplesoft dba ganesh alladi c...
# 10  peoplesoft administration vivekanand sayana ca...
# 11  arun venu experience summary experience 04 yea...
# 12  personal details name pritam biswas date birth...
# 13  rahul ahuja summary 102 years experience peopl...
# 14  hari narayana professional summary 46 years ex...
# 15  murali professional summary 46 years experienc...
# 16  priyabrata hota career objective pursuing peop...
# 17  r ahmed peoplesoft technical consultant profes...
# 18  tanna sujatha objective seeking challenging ro...
# 19  c n c address manyata tech park nagavara banga...
# 20  name ravali p curriculum vitae specialization ...
# 21  susovan bag seeking challenging position field...
# 22  kanumuru deepak reddy career objective secure ...
# 23  haripriya battina experience ui developer reac...
# 24  kamalakar reddy linked professional summary 3 ...
# 25  naveen sadhu title software developer location...
# 26  fullstack software developer web developer pav...
# 27  pragnya pattnaik expertise around 2 years expe...
# 28  sarala madasu sarala madasu 204sri geethika pr...
# 29  thirupathamma balla summary 28 year experience...
# 30  maryala vinay reddy professional summary 2 yea...
# 31  uideveloper react js developer name krishna pr...
# 32  uideveloper react js developer name krishna pr...
# 33  curriculum vitae anjani priyadarshini sr web d...
# 34  kotani durga prasad objective aspirant positio...
# 35  venkatalakshmi pedireddy software developer ex...
# 36  kambala sai surendra summary project basic kno...
# 37  mareedu lokesh babu professional overview arou...
# 38  mareedu lokesh babu professional overview arou...
# 39  md khizaruddin rauf experience currently worki...

# %%
tfidf = TfidfVectorizer()
tfidf.fit(data['Resume_Details'])
resume = tfidf.transform(data['Resume_Details'])

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score

# %%
X_train , X_test, y_train , y_test = train_test_split(resume, data['Category'], test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
models = {
    'KNeighborsClassifier':KNeighborsClassifier(),
    'LogisticRegression': LogisticRegression(),
    'RandomForestClassifier': RandomForestClassifier(),
    'SVC': SVC(),
    'MultinomialNB': MultinomialNB()
}

# %%
accuracy_scores = {}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy  = accuracy_score(y_test, y_pred)
    accuracy_scores[model_name] = accuracy
    print(f"Accuarcy of {model_name} on test data: {accuracy}")
# Out:
# Accuarcy of KNeighborsClassifier on test data: 1.0
# Accuarcy of LogisticRegression on test data: 0.95
# Accuarcy of RandomForestClassifier on test data: 1.0
# Accuarcy of SVC on test data: 0.95
# Accuarcy of MultinomialNB on test data: 0.95

# %%
for model_name, model in models.items():
    print(f"Training and evaluating {model_name}...")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    print(f"{model_name} Test Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"{model_name} Classification Report:\n{classification_report(y_test, y_pred)}")
    # Evaluate using cross-validation
    cv_scores = cross_val_score(model, resume, data['Category'], cv=5)
    print(f"Cross-validation accuracy: {cv_scores.mean():.4f}\n")
    print("=" * 50)
# Out:
# Training and evaluating KNeighborsClassifier...
# KNeighborsClassifier Test Accuracy: 1.0
# KNeighborsClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         7
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         5
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20
#
# Cross-validation accuracy: 0.9875
#
# ==================================================
# Training and evaluating LogisticRegression...
# LogisticRegression Test Accuracy: 0.95
# LogisticRegression Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89         5
#            2       0.88      1.00      0.93         7
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         5
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.95      0.96        20
# weighted avg       0.96      0.95      0.95        20
#
# Cross-validation accuracy: 0.9608
#
# ==================================================
# Training and evaluating RandomForestClassifier...
# RandomForestClassifier Test Accuracy: 1.0
# RandomForestClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         7
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         5
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20
#
# Cross-validation accuracy: 0.9733
#
# ==================================================
# Training and evaluating SVC...
# SVC Test Accuracy: 0.95
# SVC Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89         5
#            2       0.88      1.00      0.93         7
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         5
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.95      0.96        20
# weighted avg       0.96      0.95      0.95        20
#
# Cross-validation accuracy: 0.9475
#
# ==================================================
# Training and evaluating MultinomialNB...
# MultinomialNB Test Accuracy: 0.95
# MultinomialNB Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.83      1.00      0.91         5
#            2       1.00      1.00      1.00         7
#            3       1.00      0.67      0.80         3
#            4       1.00      1.00      1.00         5
#
#     accuracy                           0.95        20
#    macro avg       0.96      0.92      0.93        20
# weighted avg       0.96      0.95      0.95        20
#
# Cross-validation accuracy: 0.9625
#
# ==================================================

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Confusion Matrix for Single-Label Classification
cm = confusion_matrix(y_test, y_pred)

# Creating a heatmap for the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'],  # Update as needed
            yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])  # Update as needed

plt.title("Confusion Matrix")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculating precision, recall, and f1-score for each model
metrics = ['Precision', 'Recall', 'F1-Score']
model_metrics = {metric: {} for metric in metrics}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    model_metrics['Precision'][model_name] = precision_score(y_test, y_pred, average='weighted')
    model_metrics['Recall'][model_name] = recall_score(y_test, y_pred, average='weighted')
    model_metrics['F1-Score'][model_name] = f1_score(y_test, y_pred, average='weighted')

# Plotting precision, recall, and f1-score comparison
fig, axes = plt.subplots(1, 3, figsize=(35, 10))

# Precision
axes[0].bar(model_metrics['Precision'].keys(), model_metrics['Precision'].values(), color='orange')
axes[0].set_title('Precision Comparison')
axes[0].set_ylabel('Precision')

# Recall
axes[1].bar(model_metrics['Recall'].keys(), model_metrics['Recall'].values(), color='lightblue')
axes[1].set_title('Recall Comparison')
axes[1].set_ylabel('Recall')

# F1-Score
axes[2].bar(model_metrics['F1-Score'].keys(), model_metrics['F1-Score'].values(), color='lightgreen')
axes[2].set_title('F1-Score Comparison')
axes[2].set_ylabel('F1-Score')

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

model_name = 'KNeighborsClassifier'
model = models[model_name]
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Confusion Matrix for KNeighborsClassifier
cm = confusion_matrix(y_test, y_pred)

# Creating a heatmap for the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'],  
            yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])  

plt.title(f"Confusion Matrix for {model_name}")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the accuracy scores
plt.figure(figsize=(10, 6))
plt.bar(accuracy_scores.keys(), accuracy_scores.values(), color='skyblue')
plt.title('Model Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.ylim(0, 1.1)  # Limiting the y-axis to 1.0
plt.show()

# %%
# Dictionary to store cross-validation scores for each model
cv_scores_dict = {}

# Iterate through each model to calculate cross-validation scores
for model_name, model in models.items():
    cv_scores = cross_val_score(model, resume, data['Category'], cv=5)
    cv_scores_dict[model_name] = cv_scores.mean()  

# Plotting the cross-validation accuracy
plt.figure(figsize=(10, 6))
plt.bar(cv_scores_dict.keys(), cv_scores_dict.values(), color='lightgreen')
plt.title('Cross-validation Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Mean Cross-validation Accuracy')
plt.ylim(0, 1.1)  
plt.xticks(rotation=45)  #
plt.show()

# %% [markdown]
# #### Deployement

# %%
import joblib
import pickle

# %%
best_model_name = max(accuracy_scores, key=accuracy_scores.get)
best_model = models[best_model_name]

# %%
best_model
# Out:
# KNeighborsClassifier()

# %%
joblib.dump(best_model, f'{best_model_name}_model.pkl')
print(f"{best_model_name} is saved as the best model!")
# Out:
# KNeighborsClassifier is saved as the best model!

# %%
# Save the TfidfVectorizer
joblib.dump(tfidf, "resume_vectorizer.pkl")
# Out:
# ['resume_vectorizer.pkl']
